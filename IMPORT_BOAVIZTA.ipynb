# %%
import pandas as pd

# %%
data = 'https://raw.githubusercontent.com/Boavizta/environmental-footprint-data/main/boavizta-data-fr.csv'

# %%
df = pd.read_csv(data, sep = ';')

# %%
df[df['manufacturer'] == "HP"]
# Out:
#      manufacturer                             name   category subcategory  \
# 612            HP                11 inch Tablet PC  Workplace      Laptop
# 613            HP         14 inch 4G LTE Laptop PC  Workplace      Laptop
# 614            HP        14s Laptop PC ENERGY STAR  Workplace      Laptop
# 615            HP         15 Laptop PC ENERGY STAR  Workplace      Laptop
# 616            HP                     15 Laptop PC  Workplace      Laptop
# ...           ...                              ...        ...         ...
# 1221           HP    ZHAN 99 Mobile Workstation G3  Workplace      Laptop
# 1222           HP    ZHAN 99 Mobile Workstation G3  Workplace      Laptop
# 1223           HP  ZHAN 99 Pro G1 R MT Business PC  Workplace     Desktop
# 1224           HP     ZHAN 99 Pro G2 Microtower PC  Workplace     Desktop
# 1225           HP         ZHAN X 13 G2 Notebook PC  Workplace      Laptop
#
#      gwp_total gwp_use_ratio yearly_tec lifetime   use_location  \
# 612      182,0          0,21      17,86      4,0  North America
# 613      197,0          0,14      12,48      4,0  North America
# 614      211,0           0,2      19,93      4,0  North America
# 615      231,0          0,18      19,76      4,0  North America
# 616      228,0          0,17      18,54      4,0  North America
# ...        ...           ...        ...      ...            ...
# 1221     370,0           NaN      30,35      4,0      Worldwide
# 1222     370,0           NaN      30,35      4,0      Worldwide
# 1223      1120           NaN      218,5        5             WW
# 1224       830           NaN     129,62        5             WW
# 1225       335           NaN       14,5        4             WW
#
#         report_date  ... screen_size server_type hard_drive memory number_cpu  \
# 612        2022-2-6  ...        11,0         NaN        NaN    NaN        NaN
# 613        2022-2-6  ...        14,0         NaN        NaN    NaN        NaN
# 614       2022-3-12  ...        14,0         NaN        NaN    NaN        NaN
# 615       2022-2-10  ...        15,6         NaN        NaN    NaN        NaN
# 616       2022-3-12  ...        15,6         NaN        NaN    NaN        NaN
# ...             ...  ...         ...         ...        ...    ...        ...
# 1221      2021-4-16  ...        15,6         NaN        NaN    NaN        NaN
# 1222      2021-4-29  ...        15,6         NaN        NaN    NaN        NaN
# 1223  November 2016  ...         NaN         NaN        NaN    NaN        NaN
# 1224  November 2016  ...         NaN         NaN        NaN    NaN        NaN
# 1225  December 2016  ...        15,6         NaN        NaN    NaN        NaN
#
#      height  added_date       add_method gwp_transport_ratio  gwp_eol_ratio
# 612     NaN  2022-04-09   HP Auto Parser                0,05           0,01
# 613     NaN  2022-04-09   HP Auto Parser                0,05            0,0
# 614     NaN  2022-04-09   HP Auto Parser                0,05            0,0
# 615     NaN  2022-04-09   HP Auto Parser                0,06            0,0
# 616     NaN  2022-04-09   HP Auto Parser                0,06            0,0
# ...     ...         ...              ...                 ...            ...
# 1221    NaN  2022-04-09   HP Auto Parser                 NaN            NaN
# 1222    NaN  2022-04-09   HP Auto Parser                 NaN            NaN
# 1223    NaN  01-11-2020  Initial Parsing                 NaN            NaN
# 1224    NaN  01-11-2020  Initial Parsing                 NaN            NaN
# 1225    NaN  01-11-2020  Initial Parsing                 NaN            NaN
#
# [614 rows x 25 columns]
