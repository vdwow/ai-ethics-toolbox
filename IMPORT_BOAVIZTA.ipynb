# %%
import pandas as pd

# %%
data = 'https://raw.githubusercontent.com/Boavizta/environmental-footprint-data/main/boavizta-data-fr.csv'

# %%
df = pd.read_csv(data, sep = ';', error_bad_lines=False)
# Out:
# C:\Users\Valentin\AppData\Local\Temp\ipykernel_19556\1762426117.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(data, sep = ';', error_bad_lines=False)

# %%
df
# Out:
#      manufacturer                                               name  \
# 0           Apple          13-inch MacBook Air (M1 CPU) 256GB - 2020
# 1           Apple          13-inch MacBook Air (M1 CPU) 512GB - 2020
# 2           Apple  13-inch MacBook Air with Retina display (1,1GH...
# 3           Apple  13-inch MacBook Air with Retina display (1,1GH...
# 4           Apple  13-inch MacBook Pro (1,4GHz quad-core CPU) 256...
# ...           ...                                                ...
# 1901      Seagate                   Nytro 1551 XA1920ME10083 1,92 TB
# 1902      Seagate                    Nytro 3331 XS7680SE70004 7,68TB
# 1903      Seagate         OneStor SP2584 Extensible Storage Platform
# 1904      Seagate                                 Pulsar 2 800GB SSD
# 1905      Seagate                                  THUNDERBUG 300 Go
#
#         category subcategory gwp_total gwp_use_ratio yearly_tec lifetime  \
# ...
